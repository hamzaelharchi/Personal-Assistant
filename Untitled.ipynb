# %%
#import library
import speech_recognition as sr

# Initialize recognizer class (for recognizing the speech)
r = sr.Recognizer()

# Reading Audio file as source
# listening the audio file and store in audio_text variable

with sr.AudioFile('t3.wav') as source:
    
    audio_text = r.listen(source)
    
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
     
    except:
         print('Sorry.. run again...')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:203, in AudioFile.__enter__(self)
#     201 try:
#     202     # attempt to read the file as WAV
# --> 203     self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     204     self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\wave.py:509, in open(f, mode)
#     508 if mode in ('r', 'rb'):
# --> 509     return Wave_read(f)
#     510 elif mode in ('w', 'wb'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\wave.py:163, in Wave_read.__init__(self, f)
#     162 try:
# --> 163     self.initfp(f)
#     164 except:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\wave.py:128, in Wave_read.initfp(self, file)
#     127 self._soundpos = 0
# --> 128 self._file = Chunk(file, bigendian = 0)
#     129 if self._file.getname() != b'RIFF':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\chunk.py:63, in Chunk.__init__(self, file, align, bigendian, inclheader)
#      62 if len(self.chunkname) < 4:
# ---> 63     raise EOFError
#      64 try:
#
# EOFError:
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:208, in AudioFile.__enter__(self)
#     206 try:
#     207     # attempt to read the file as AIFF
# --> 208     self.audio_reader = aifc.open(self.filename_or_fileobject, "rb")
#     209     self.little_endian = False  # AIFF is a big-endian format
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:917, in open(f, mode)
#     916 if mode in ('r', 'rb'):
# --> 917     return Aifc_read(f)
#     918 elif mode in ('w', 'wb'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:352, in Aifc_read.__init__(self, f)
#     351 try:
# --> 352     self.initfp(file_object)
#     353 except:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:314, in Aifc_read.initfp(self, file)
#     313 self._file = file
# --> 314 chunk = Chunk(file)
#     315 if chunk.getname() != b'FORM':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\chunk.py:63, in Chunk.__init__(self, file, align, bigendian, inclheader)
#      62 if len(self.chunkname) < 4:
# ---> 63     raise EOFError
#      64 try:
#
# EOFError:
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:234, in AudioFile.__enter__(self)
#     233 try:
# --> 234     self.audio_reader = aifc.open(aiff_file, "rb")
#     235 except (aifc.Error, EOFError):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:917, in open(f, mode)
#     916 if mode in ('r', 'rb'):
# --> 917     return Aifc_read(f)
#     918 elif mode in ('w', 'wb'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:358, in Aifc_read.__init__(self, f)
#     356 else:
#     357     # assume it is an open file object already
# --> 358     self.initfp(f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:314, in Aifc_read.initfp(self, file)
#     313 self._file = file
# --> 314 chunk = Chunk(file)
#     315 if chunk.getname() != b'FORM':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\chunk.py:63, in Chunk.__init__(self, file, align, bigendian, inclheader)
#      62 if len(self.chunkname) < 4:
# ---> 63     raise EOFError
#      64 try:
#
# EOFError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [3], in <module>
#       5 r = sr.Recognizer()
#       7 # Reading Audio file as source
#       8 # listening the audio file and store in audio_text variable
# ---> 10 with sr.AudioFile('t3.wav') as source:
#      12     audio_text = r.listen(source)
#      14 # recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:236, in AudioFile.__enter__(self)
#     234             self.audio_reader = aifc.open(aiff_file, "rb")
#     235         except (aifc.Error, EOFError):
# --> 236             raise ValueError("Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format")
#     237         self.little_endian = False  # AIFF is a big-endian format
#     238 assert 1 <= self.audio_reader.getnchannels() <= 2, "Audio must be mono or stereo"
#
# ValueError: Audio file could not be read as PCM WAV, AIFF/AIFF-C, or Native FLAC; check if file is corrupted or in another format

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

data, sampling_rate =librosa.load('t3.wav')
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)
data.shape
# Out:
# C:\Users\hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:149, in load(path, sr, mono, offset, duration, dtype, res_type)
#     148 try:
# --> 149     with sf.SoundFile(path) as sf_desc:
#     150         sr_native = sf_desc.samplerate
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soundfile.py:740, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     738 self._info = _create_info_struct(file, mode, samplerate, channels,
#     739                                  format, subtype, endian)
# --> 740 self._file = self._open(file, mode_int, closefd)
#     741 if set(mode).issuperset('r+') and self.seekable():
#     742     # Move write position to 0 (like in Python file objects)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soundfile.py:1264, in SoundFile._open(self, file, mode_int, closefd)
#    1263     raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1264 _error_check(_snd.sf_error(file_ptr),
#    1265              "Error opening {0!r}: ".format(self.name))
#    1266 if mode_int == _snd.SFM_WRITE:
#    1267     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1268     # when opening a named pipe in SFM_WRITE mode.
#    1269     # See http://github.com/erikd/libsndfile/issues/77.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soundfile.py:1455, in _error_check(err, prefix)
#    1454 err_str = _snd.sf_error_number(err)
# -> 1455 raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#
# RuntimeError: Error opening 't3.wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# Input In [4], in <module>
#       2 import librosa.display
#       3 import matplotlib.pyplot as plt
# ----> 5 data, sampling_rate =librosa.load('t3.wav')
#       6 plt.figure(figsize=(12, 4))
#       7 librosa.display.waveplot(data, sr=sampling_rate)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:166, in load(path, sr, mono, offset, duration, dtype, res_type)
#     164 if isinstance(path, (str, pathlib.PurePath)):
#     165     warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167 else:
#     168     raise (exc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:190, in __audioread_load(path, offset, duration, dtype)
#     184 """Load an audio buffer using audioread.
#     185
#     186 This loads one block at a time, and then concatenates the results.
#     187 """
#     189 y = []
# --> 190 with audioread.audio_open(path) as input_file:
#     191     sr_native = input_file.samplerate
#     192     n_channels = input_file.channels
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\audioread\__init__.py:111, in audio_open(path, backends)
#     109 for BackendClass in backends:
#     110     try:
# --> 111         return BackendClass(path)
#     112     except DecodeError:
#     113         pass
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\audioread\rawread.py:65, in RawAudioFile.__init__(self, filename)
#      62 self._fh = open(filename, 'rb')
#      64 try:
# ---> 65     self._file = aifc.open(self._fh)
#      66 except aifc.Error:
#      67     # Return to the beginning of the file to try the next reader.
#      68     self._fh.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:917, in open(f, mode)
#     915         mode = 'rb'
#     916 if mode in ('r', 'rb'):
# --> 917     return Aifc_read(f)
#     918 elif mode in ('w', 'wb'):
#     919     return Aifc_write(f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:358, in Aifc_read.__init__(self, f)
#     355         raise
#     356 else:
#     357     # assume it is an open file object already
# --> 358     self.initfp(f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\aifc.py:314, in Aifc_read.initfp(self, file)
#     312 self._soundpos = 0
#     313 self._file = file
# --> 314 chunk = Chunk(file)
#     315 if chunk.getname() != b'FORM':
#     316     raise Error('file does not start with FORM id')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\chunk.py:63, in Chunk.__init__(self, file, align, bigendian, inclheader)
#      61 self.chunkname = file.read(4)
#      62 if len(self.chunkname) < 4:
# ---> 63     raise EOFError
#      64 try:
#      65     self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:
